# %%
a=10
b=20
a+b
# Out:
# 30

# %% [markdown]
# Mark down mode learning
#
# esc+m: code to markdown
# esc+y: markdown to code mode
#
# when a cell in markdown mode there is no square brackets

# %% [markdown]
# # python
#
# # python
#
# ## python

# %% [markdown]
# - today Im learning python
#
# - It is very Interresting
#
# - I am understanding **platform**
#
#     - There are two modes
#
#     - To write the code we have **code mode**
#
#     - To wite the text we have **markdown mode**

# %% [markdown]
# **kernel**

# %%
a=10
b=20
a+b
# Out:
# 30

# %%
import time
time.sleep(5)
print('hello')
# Out:
# hello

# %%
a=10
a
# Out:
# 10

# %%
a=20
a
# Out:
# 20

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

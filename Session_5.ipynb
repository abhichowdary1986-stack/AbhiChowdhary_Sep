# %%
if True:
    print("hai")
    if True:
        print("hello")
        if True: 
            print("hi")
        else:
            print("hi1")
    else:
        print("hello2")
else:
    print("bye")
# Out:
# hai
# hello
# hi

# %%
if True:
    print("I am the Father")
    if True:
        print("I am the First Son")
        if True: 
            print("I am the Second Son")
        else:
            print("I am Mother")
    else:
        print("I am wife")
else:
    print("bye")
# Out:
# I am the Father
# I am the First Son
# I am the Second Son

# %%
# even and odd
# ask the user enter a value
# prit if the number is even
# otherwise print odd


num = eval(input("Enter a number:"))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number: 20
# Even

# %%
10%2
# Out:
# 0

# %%
Str = input("Enter a Institute name")
Str1 = "NareshIT"

if Str.lower() == Str1.lower():
    print("Good")
else:
    print("Bad")
# Out:
# Enter a Institute name NARESHIT
# Good

# %%
# 2 persons playing the game

num1 = eval(input("Enter Number1:"))
num2 = eval(input("Enter Number2:"))

if num1==num2:
    print("Won")
else:
    print("Lost")
# Out:
# Enter Number1: 2
# Enter Number2: 2
# Won

# %%
# Random

import random
random.randint(1,10)
# Out:
# 8

# %%
import random
num1 = random.randint(1,10)
num2 = eval(input("Enter Number2:"))

if num1==num2:
    print("Won")
else:
    print("Lost")
# Out:
# Enter Number2: 2
# Won

# %%
#WAP - Write a Program

Inst_name = input("Enter institute name")
Course_name = input("Enter course name")

if Inst_name.lower() == 'NARESHIT'.lower():
    if Course_name.lower() == 'AI'.lower():
        print("Lise is secure")
    else:
        print("katam")
else:
    print("katam")
# Out:
# Enter institute name NARESHIT
# Enter course name A
# katam

# %%
distance = eval(input("Enter a distance:"))
if distance >= 25:
    print(distance*2)
else:
    print("enjoy free ride")
# Out:
# Enter a distance: 25
# 50

# %%
Inst_name = input("Enter institute name")
Course_name = input("Enter course name")

con1=Inst_name.lower() == 'NARESHIT'.lower()
con2=Course_name.lower() == 'AI'.lower()
if con1 and con2:
    print('good choice')
else:
    print('katam')
# Out:
# Enter institute name Nareshit
# Enter course name AI
# good choice

# %%
distance=eval(input('enter a distance:'))
if distance>=25:
    charge=eval(input('enter the charge:'))
    charge_distance=distance-25
    total_charge=charge_distance*charge
    print(f'The total charge is: {total_charge}')
else:
    print('enjoy the free ride')
# Out:
# enter a distance: 50
# enter the charge: 2
# The total charge is: 50

# %%
gender=input('Enter the gender:')
if gender.lower() == 'male'.lower():
    distance=eval(input('enter a distance:'))
    if distance>=25:
        charge=eval(input('enter the charge:'))
        charge_distance=distance-25
        total_charge=charge_distance*charge
        print(f'The total charge is: {total_charge}')
    else:
        print('your distance less than 25')
        print('enjoy the free ride')
else:
    print('enjoy the free ride as you are female')
# Out:
# Enter the gender: male
# enter a distance: 24
# your distance less than 25
# enjoy the free ride

# %% [markdown]
# If Con1:
#     ans1
# elif con2:
#     ans2
# else:
#     ans3

# %%
per = eval(input('Enter the Percentage:'))
if per >= 75:
    print('A')
elif per >=60 and per<75:
    print('B')
elif per >=45 and per<60:
    print('C')
elif per >=35 and per<45:
    print('D')
else:
    print('fail')
# Out:
# Enter the Percentage: 20
# fail

# %%
per = eval(input('Enter the Percentage:'))
if per >= 75:
    print('A')
elif per >=60:
    print('B')
elif per >=45:
    print('C')
elif per >=35:
    print('D')
else:
    print('fail')
# Out:
# Enter the Percentage: 50
# C

# %%
age = eval(input('Enter your age:'))
if age >= 100:
    print('Unlucy')
elif age >=60:
    print('Senior Citizen')
elif age >=30:
    print('Middle Aged')
elif age >=20:
    print('Young')
elif age >=13:
    print('Teenage')
else:
    print('kid')
# Out:
# Enter your age: 28
# Young
